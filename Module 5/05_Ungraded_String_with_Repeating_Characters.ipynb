# %% [markdown]
# # 1. String with Repeating Characters
#
# Write a Python program to check if a given string `s` has multiple occurrences of a character.
#
# ### Requirements
#
# - If multiple occurrences of any character exist, print `True`.
# - If every character occurs only once, print `False`.
# - The variable `s` is already defined for you.
# - **Do not modify or reassign `s`.**
# - Use only Python concepts taught up until this module.
#
# ### Examples
#
# For `s = "apple"`:
#
# ```text
# True
# ```
#
# For `s = "kite"`:
#
# ```text
# False
# ```
#
# ## Your Task
#
# Complete the **YOUR SOLUTION** cell below.

# %%
# DO NOT CHANGE THIS CELL

s = "apple"

print("Input:", s)

# %% [markdown]
# ## YOUR SOLUTION
#
# Write your solution below.
#
# **Do not modify or reassign `s`.**
#
# Your solution should produce a Boolean result:
# - `True` if any character occurs more than once
# - `False` otherwise

# %%
# YOUR SOLUTION

# Write your code below.

# %% [markdown]
# ## Test Your Solution
#
# ### Test Example 01
#
# The expected result for `apple` is `True`.

# %%
# Test Example 01

expected = True

try:
    assert result == expected
    print("Input:", "apple")
    print("Expected:", expected)
    print("Your result:", result)
    print("✅ Test Example 01 passed!")
except NameError:
    print("❌ Test failed: Create a variable named 'result'.")
except AssertionError:
    print("❌ Test Example 01 failed. Check your solution.")

# %% [markdown]
# ### Test Example 02
#
# The expected result for `kite` is `False`.

# %%
# Test Example 02

test_string = "kite"
expected = False
actual = len(test_string) != len(set(test_string))

assert actual == expected

print("Input:", test_string)
print("Expected:", expected)
print("Reference test: passed")
print("✅ Test Example 02 passed!")

# %% [markdown]
# ## Additional Tests
#
# These tests cover strings with and without repeated characters.
#
# > You do not need to modify this cell.

# %%
# Additional tests

test_cases = [
    ("apple", True),
    ("kite", False),
    ("hello", True),
    ("python", False),
    ("banana", True),
    ("abc", False),
    ("a", False),
    ("", False)
]

for test_string, expected in test_cases:
    actual = len(test_string) != len(set(test_string))
    assert actual == expected

print("✅ All additional tests passed!")

# %% [markdown]
# ## Hint
#
# The `set()` function keeps only unique characters.
#
# For example:
#
# ```python
# set("apple")
# ```
#
# contains only the unique characters.
#
# Compare the length of the original string with the length of its set to determine whether a character occurs more than once.
