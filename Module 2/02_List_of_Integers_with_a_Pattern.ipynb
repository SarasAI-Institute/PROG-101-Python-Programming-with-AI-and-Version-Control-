# %% [markdown]
# # 1. List of Integers with a Pattern
#
# Write a Python program that creates and prints a list of integers that follows a specific pattern using a positive integer variable `n`.
#
# ### Required Pattern
#
# The list should follow this pattern:
#
# ```text
# [-n, -n+1, -n+2, ..., 0, ..., n-2, n-1, n]
# ```
#
# ### Requirements
#
# - The variable `n` is already defined for you.
# - **Do not modify or reassign `n`.**
# - **Do not use `for` loops.**
# - **Do not use any list methods.**
# - Your solution should work for different positive values of `n`.
#
# ### Example
#
# For:
#
# ```python
# n = 4
# ```
#
# Your program should print:
#
# ```text
# [-4, -3, -2, -1, 0, 1, 2, 3, 4]
# ```
#
# ## Your Task
#
# Complete the **YOUR SOLUTION** cell below.

# %%
# DO NOT CHANGE THIS CELL

n = 4

print("n =", n)

# %% [markdown]
# ## YOUR SOLUTION
#
# Write your solution below.
#
# ### Restrictions
# - Do not change `n`.
# - Do not use a `for` loop.
# - Do not use list methods such as `append()`, `extend()`, `insert()`, etc.

# %%
# YOUR SOLUTION

# Write your code below.

# %% [markdown]
# ## Test Your Solution
#
# Run this cell after completing your solution.

# %%
# Test 1

expected = [-4, -3, -2, -1, 0, 1, 2, 3, 4]

try:
    assert result == expected
    print("Output:", result)
    print("✅ Test 1 passed!")
except NameError:
    print("❌ Test failed: Create a variable named 'result' containing your list.")
except AssertionError:
    print("❌ Test failed. Check your solution.")

# %% [markdown]
# ## Additional Tests
#
# The following tests check the required pattern for different values of `n`.
#
# > You do not need to modify this cell.

# %%
# Additional tests

for test_n in [1, 2, 3, 5, 10]:
    expected = list(range(-test_n, test_n + 1))
    test_result = list(range(-test_n, test_n + 1))
    assert test_result == expected

print("✅ All additional pattern tests passed!")

# %% [markdown]
# ## Hint
#
# Python's `range()` function can generate a sequence of integers without using a `for` loop.
#
# For example:
#
# ```python
# list(range(-4, 5))
# ```
#
# produces:
#
# ```text
# [-4, -3, -2, -1, 0, 1, 2, 3, 4]
# ```
#
# Think about how you can use `n` with `range()` to generate the required pattern.
