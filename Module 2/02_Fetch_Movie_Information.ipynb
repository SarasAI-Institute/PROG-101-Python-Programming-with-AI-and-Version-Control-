# %% [markdown]
# # 1. Fetch Movie Information
#
# You are provided with four lists containing information about movies.
#
# Each element at the **same index position** across these lists corresponds to the same movie.
#
# For example, the first item in each list corresponds to **Prometheus**.
#
# ```python
# m_name = ['Prometheus', 'Split', 'Sing', 'Suicide Squad', 'The Great Wall']
# m_yor = [2012, 2016, 2015, 2014, 2017]
# m_rating = [8.1, 7.5, 6.7, 5.3, 7.1]
# m_reviews = [485820, 157606, 60545, 393727, 56036]
# ```
#
# You are also given a variable `movie_name` containing the name of a specific movie.
#
# ### Your Task
#
# Write a Python program that displays the information for the specified movie.
#
# ### Information to Display
#
# - Movie's name
# - Movie's release year
# - Movie's rating
# - Movie's number of reviews
#
# ### Requirements
#
# - The lists `m_name`, `m_yor`, `m_rating`, and `m_reviews` are already defined.
# - The variable `movie_name` is already defined.
# - **Do not modify or reassign any of these variables.**
# - Your solution should work for different movie names.
#
# ### Example
#
# For:
#
# ```python
# movie_name = 'The Great Wall'
# ```
#
# Your program should print:
#
# ```text
# Movie Name : The Great Wall
# Movie Release Year : 2017
# Movie Rating : 7.1
# Movie Reviews : 56036
# ```
#
# ## Your Task
#
# Complete the **YOUR SOLUTION** cell below.

# %%
# DO NOT CHANGE THIS CELL

m_name = ['Prometheus', 'Split', 'Sing', 'Suicide Squad', 'The Great Wall']
m_yor = [2012, 2016, 2015, 2014, 2017]
m_rating = [8.1, 7.5, 6.7, 5.3, 7.1]
m_reviews = [485820, 157606, 60545, 393727, 56036]

movie_name = 'The Great Wall'

print("Movie to find:", movie_name)

# %% [markdown]
# ## YOUR SOLUTION
#
# Write your solution below.
#
# Use the movie name to find its position in `m_name`, then use that position to retrieve the corresponding year, rating, and number of reviews.

# %%
# YOUR SOLUTION

# Write your code below.

# %% [markdown]
# ## Test Your Solution
#
# Run this cell after completing your solution.

# %%
# Test 1

expected = {
    "name": "The Great Wall",
    "year": 2017,
    "rating": 7.1,
    "reviews": 56036
}

try:
    assert movie_info_result["name"] == expected["name"]
    assert movie_info_result["year"] == expected["year"]
    assert movie_info_result["rating"] == expected["rating"]
    assert movie_info_result["reviews"] == expected["reviews"]

    print("Movie Name :", movie_info_result["name"])
    print("Movie Release Year :", movie_info_result["year"])
    print("Movie Rating :", movie_info_result["rating"])
    print("Movie Reviews :", movie_info_result["reviews"])
    print("✅ Test 1 passed!")

except NameError:
    print("❌ Test failed: Create a variable named 'movie_info_result' containing the movie information.")
except (AssertionError, KeyError):
    print("❌ Test failed. Check your solution.")

# %% [markdown]
# ## Additional Tests
#
# The following tests check that the correct movie information can be retrieved for different movie names.
#
# > You do not need to modify this cell.

# %%
# Additional test cases

test_cases = [
    ("Prometheus", 2012, 8.1, 485820),
    ("Split", 2016, 7.5, 157606),
    ("Sing", 2015, 6.7, 60545),
    ("Suicide Squad", 2014, 5.3, 393727),
    ("The Great Wall", 2017, 7.1, 56036)
]

for name, expected_year, expected_rating, expected_reviews in test_cases:
    index = m_name.index(name)

    assert m_yor[index] == expected_year
    assert m_rating[index] == expected_rating
    assert m_reviews[index] == expected_reviews

print("✅ All additional tests passed!")

# %% [markdown]
# ## Hint
#
# The Python `list.index()` method can be used to find the position of a movie in `m_name`.
#
# For example:
#
# ```python
# index = m_name.index(movie_name)
# ```
#
# You can then use the same `index` to retrieve the corresponding values from the other lists:
#
# ```python
# m_yor[index]
# m_rating[index]
# m_reviews[index]
# ```
