# %% [markdown]
# # Q1. User Authentication System
#
# ## Problem 01: User Authentication System
#
# Imagine you are building part of a Music Management Application where users need to either sign up or sign in to access their music and playlists.
#
# Your task is to create a **User Authentication System** that handles registration and login.
#
# ### Development Workflow
#
# The original assignment is designed as a standalone Python script. In Google Colab, you will develop and test the same program interactively.
#
# Your program must include:
#
# ```python
# def main():
#     # menu loop
#
# if __name__ == "__main__":
#     main()
# ```
#
# When the script is run, `main()` should launch the menu.
#
# ### Requirements
#
# Your program should present a menu with:
#
# ```text
# Menu:
# 1. Signup
# 2. Sign-in
# 3. Exit
# ```
#
# #### 1. Signup
#
# Collect:
#
# - Email ID
# - Password
# - First Name
# - Last Name
# - Age
#
# Store the information in `user_data`.
#
# If the email already exists, display:
#
# ```text
# Email ID already exists. Please use a different one.
# ```
#
# #### 2. Sign-in
#
# Prompt for:
#
# - Email ID
# - Password
#
# If the credentials match, display:
#
# ```text
# Welcome, <first_name> <last_name>!
# ```
#
# If the credentials are incorrect, display:
#
# ```text
# Invalid email ID or password.
# ```
#
# #### 3. Exit
#
# Display:
#
# ```text
# Exiting the application. Goodbye!
# ```
#
# ### Important
#
# - You **must** use the `user_data` dictionary provided below.
# - Do not rename or remove `user_data`.
# - `user_data` must persist across signup and sign-in operations.
# - Implement the functions `signup`, `signin`, and `main`.
# - Handle invalid input gracefully.
# - Use only built-in Python functionality.
# - Follow the required output format exactly.

# %%
user_data = {
    "john.doe@example.com":      {"password": "john123",    "first_name": "John",    "last_name": "Doe",     "age": 28},
    "jane.smith@example.com":    {"password": "jane456",    "first_name": "Jane",    "last_name": "Smith",   "age": 32},
    "alice.jones@example.com":   {"password": "alice789",   "first_name": "Alice",   "last_name": "Jones",   "age": 24},
    "bob.brown@example.com":     {"password": "bob101",     "first_name": "Bob",     "last_name": "Brown",   "age": 30},
    "charlie.white@example.com": {"password": "charlie202","first_name": "Charlie", "last_name": "White",  "age": 35},
    "diana.green@example.com":   {"password": "diana303",   "first_name": "Diana",   "last_name": "Green",   "age": 27},
    "evan.black@example.com":    {"password": "evan404",    "first_name": "Evan",    "last_name": "Black",   "age": 29},
    "fiona.red@example.com":     {"password": "fiona505",   "first_name": "Fiona",   "last_name": "Red",     "age": 22},
    "george.blue@example.com":   {"password": "george606",  "first_name": "George",  "last_name": "Blue",    "age": 26},
    "hannah.yellow@example.com": {"password": "hannah707",  "first_name": "Hannah",  "last_name": "Yellow",  "age": 31}
}

# %% [markdown]
# ## YOUR SOLUTION
#
# Complete the program in the cell below.
#
# ### Required Functions
#
# Your solution must include:
#
# ```python
# def signup():
#     ...
#
# def signin():
#     ...
#
# def main():
#     ...
# ```
#
# At the bottom of your solution, include:
#
# ```python
# if __name__ == "__main__":
#     main()
# ```
#
# ### Expected Menu
#
# Your program should display:
#
# ```text
# Menu:
# 1. Signup
# 2. Sign-in
# 3. Exit
# ```
#
# Use the exact messages specified in the assignment.
#
# > **Important:** Do not create another `user_data` dictionary. Use the dictionary provided above.

# %%
# WRITE YOUR CODE HERE

# Implement:
# 1. signup()
# 2. signin()
# 3. main()
#
# Remember to include:
# if __name__ == "__main__":
#     main()

# %% [markdown]
# ## Test Your Solution
#
# Because this is an interactive program, run your solution cell first and then use the test scenarios below to manually verify your program.
#
# ### Test 1 — Exit
#
# At the menu, enter:
#
# ```text
# 3
# ```
#
# Expected output:
#
# ```text
# Exiting the application. Goodbye!
# ```
#
# Click/run your solution cell and test this scenario.

# %%
# Test 1 — Exit
# Expected menu choice: 3
print("Test input: 3")
print("Expected output:")
print("Exiting the application. Goodbye!")

# %% [markdown]
# ### Test 2 — Sign-in Failure
#
# Use:
#
# ```text
# Email ID: john.doe@example.com
# Password: wrongpassword
# ```
#
# Expected output:
#
# ```text
# Invalid email ID or password.
# ```
#
# The existing user `john.doe@example.com` has password `john123`, so `wrongpassword` should fail.

# %%
# Test 2 — Sign-in Failure
print("Email ID: john.doe@example.com")
print("Password: wrongpassword")
print("Expected output:")
print("Invalid email ID or password.")

# %% [markdown]
# ### Test 3 — Sign-in Success
#
# Use:
#
# ```text
# Email ID: john.doe@example.com
# Password: john123
# ```
#
# Expected output:
#
# ```text
# Welcome, John Doe!
# ```

# %%
# Test 3 — Sign-in Success
print("Email ID: john.doe@example.com")
print("Password: john123")
print("Expected output:")
print("Welcome, John Doe!")

# %% [markdown]
# ### Test 4 — Signup with Existing Email
#
# Choose Signup and enter:
#
# ```text
# Email ID: jane.smith@example.com
# ```
#
# Expected output:
#
# ```text
# Email ID already exists. Please use a different one.
# ```
#
# The program should not overwrite the existing user.

# %%
# Test 4 — Signup Existing Email
print("Email ID: jane.smith@example.com")
print("Expected output:")
print("Email ID already exists. Please use a different one.")

# %% [markdown]
# ### Test 5 — Successful Signup
#
# Choose Signup and enter:
#
# ```text
# Email ID: user1@gmail.com
# Password: pass123
# First Name: GS
# Last Name: SG
# Age: 32
# ```
#
# Expected output:
#
# ```text
# Registration successful!
# ```
#
# After registration, verify that the new user can sign in using:
#
# ```text
# Email ID: user1@gmail.com
# Password: pass123
# ```
#
# Expected output:
#
# ```text
# Welcome, GS SG!
# ```

# %%
# Test 5 — Signup Success
print("Email ID: user1@gmail.com")
print("Password: pass123")
print("First Name: GS")
print("Last Name: SG")
print("Age: 32")
print("Expected output:")
print("Registration successful!")
print()
print("Then sign in with user1@gmail.com / pass123")
print("Expected output:")
print("Welcome, GS SG!")

# %% [markdown]
# ## Submission Checklist
#
# Before submitting your solution, verify that:
#
# - [ ] `user_data` is included exactly as provided.
# - [ ] `signup()` is implemented.
# - [ ] `signin()` is implemented.
# - [ ] `main()` is implemented.
# - [ ] The menu contains Signup, Sign-in, and Exit.
# - [ ] Existing email IDs are detected.
# - [ ] New users are added to `user_data`.
# - [ ] Sign-in validates both email and password.
# - [ ] Successful sign-in displays the user's first and last name.
# - [ ] Invalid credentials display the required error message.
# - [ ] Exit displays the required goodbye message.
# - [ ] The following appears at the bottom of the program:
#
# ```python
# if __name__ == "__main__":
#     main()
# ```
#
# - [ ] The program has been tested with all five scenarios above.

# %% [markdown]
# ## Submission
#
# For the original Codio submission:
#
# - **File name:** `SC_Q1.py`
# - Develop and test your program locally or in this Colab notebook.
# - Copy only the contents of your completed Python script into Codio.
# - Make sure the required `main()` function and `if __name__ == "__main__":` block are included.
#
# **Important:** The grading system may compare output exactly. Use the specified menu and output messages without adding extra text.
