# %% [markdown]
# # Q3. Songs Management System
#
# ## Problem 03: Songs Management System
#
# Imagine you are building part of a Music Management Application where users need to search for songs and explore their information.
#
# Your task is to create a **Songs Management System** that loads a song database at startup and allows users to:
#
# 1. Search for a song by title
# 2. Search for all songs by an artist
# 3. Exit the application
#
# ### Development Workflow
#
# The original assignment is designed as a standalone Python script. In Google Colab, you will develop and test the same program interactively.
#
# Your program must include:
#
# ```python
# def main():
#     # load database and run menu
#
# if __name__ == "__main__":
#     main()
# ```
#
# ### Important File Requirement
#
# Your program must read from a file named exactly:
#
# ```text
# songs_database.txt
# ```
#
# Do **not** change this file name.
#
# The backend tests will create and use `songs_database.txt`.
#
# ### User Menu
#
# When the program starts, it should load the database and then display:
#
# ```text
# --- User Menu ---
#
# 1. Search for a Song by Title
# 2. Search for All Songs by an Artist
# 3. Exit
# ```
#
# ### Required Functions
#
# Your solution must implement:
#
# ```python
# load_database()
# search_by_title()
# search_by_artist()
# main()
# ```
#
# Use only built-in Python modules.
#
# > **Important:** Do not use `exit()` to terminate the program. Use `break` to leave the menu loop.
#
# > **Important:** Match the required prompts and messages exactly because the original assignment uses automated checks.

# %% [markdown]
# ## Sample `songs_database.txt`
#
# For Colab practice, the next cell creates the required file in the current working directory.
#
# The backend version of the assignment will provide its own `songs_database.txt`, so your solution should **always read the file by this exact name**.

# %%
# Create the sample songs_database.txt file for testing in Colab.

song_database = '''"Shape of You","Ed Sheeran","Divide","Pop","3:53"
"Blinding Lights","The Weeknd","After Hours","Synth Pop","3:20"
"Levitating","Dua Lipa","Future Nostalgia","Disco","3:24"
"Rolling in the Deep","Adele","21","Pop","3:48"
"Stay","The Kid LAROI","FCK LOVE 3","Hip Hop","2:21"
"Bad Guy","Billie Eilish","When We All Fall Asleep Where Do We Go","Pop","3:14"
"Someone Like You","Adele","21","Pop","4:45"
"Watermelon Sugar","Harry Styles","Fine Line","Pop","3:03"
"Dance Monkey","Tones and I","The Kids Are Coming","Pop","3:29"
"Peaches","Justin Bieber","Justice","R&B","3:18"
"Good 4 U","Olivia Rodrigo","Sour","Pop","2:58"
"drivers license","Olivia Rodrigo","Sour","Pop","4:02"
"Dynamite","BTS","BE","K Pop","3:19"
"Don't Start Now","Dua Lipa","Future Nostalgia","Disco","3:03"
"Senorita","Shawn Mendes and Camila Cabello","Senorita","Pop","3:11"
"Perfect","Ed Sheeran","Divide","Pop","4:23"
"Shallow","Lady Gaga and Bradley Cooper","A Star is Born","Pop","3:37"
"I Will Always Love You","Whitney Houston","The Bodyguard","Pop","4:31"
"Uptown Funk","Mark Ronson ft Bruno Mars","Uptown Special","Funk","4:30"
"Lose Yourself","Eminem","8 Mile","Hip Hop","5:26"
"Thinking Out Loud","Ed Sheeran","Multiply","Pop","4:41"
"Viva La Vida","Coldplay","Viva La Vida or Death and All His Friends","Rock","4:02"
"My Heart Will Go On","Celine Dion","Titanic","Pop","4:40"'''

with open("songs_database.txt", "w", encoding="utf-8") as f:
    f.write(song_database)

print("songs_database.txt created successfully.")

# %% [markdown]
# ## YOUR SOLUTION
#
# Write your complete Songs Management System in the cell below.
#
# ### Required Behavior
#
# #### Search by Title
#
# Prompt:
#
# ```text
# Enter the song title to search:
# ```
#
# Perform a **case-insensitive** search.
#
# If found:
#
# ```text
# Found: '<Title>' by <Artist> (Album: <Album>, Genre: <Genre>, Duration: <Duration>)
# ```
#
# If not found:
#
# ```text
# Song title '<input>' does not exist in the database.
# ```
#
# #### Search by Artist
#
# Prompt:
#
# ```text
# Enter the artist's name to search:
# ```
#
# Perform a **case-insensitive** search.
#
# For each matching song:
#
# ```text
# Found: '<Title>' (Album: <Album>, Genre: <Genre>, Duration: <Duration>)
# ```
#
# If no songs are found:
#
# ```text
# No songs found for artist '<input>'.
# ```
#
# #### Exit
#
# Display:
#
# ```text
# Exiting the Songs Management System. Goodbye!
# ```
#
# Then use `break` to leave the menu loop.

# %%
# WRITE YOUR CODE HERE

# Implement:
# 1. load_database()
# 2. search_by_title()
# 3. search_by_artist()
# 4. main()
#
# Remember:
# - Always read songs_database.txt
# - Searches must be case-insensitive
# - Use break to exit the menu
# - Do not use exit()
#
# Required at the bottom:
# if __name__ == "__main__":
#     main()

# %% [markdown]
# ## Test Your Solution
#
# Because this is an interactive application, first run your solution cell and then test the scenarios below.
#
# ### Test 1 — Search by Song Title
#
# Choose:
#
# ```text
# 1
# ```
#
# Enter:
#
# ```text
# Uptown Funk
# ```
#
# Expected:
#
# ```text
# Searching for songs with title: 'Uptown Funk'
# Found: 'Uptown Funk' by Mark Ronson ft Bruno Mars (Album: Uptown Special, Genre: Funk, Duration: 4:30)
# ```
#
# Also test a different capitalization such as:
#
# ```text
# uptown funk
# ```
#
# The search should still find the song.

# %%
# Test 1 — Search by Title
print("Test input:")
print("1")
print("Uptown Funk")
print()
print("Expected:")
print("Searching for songs with title: 'Uptown Funk'")
print("Found: 'Uptown Funk' by Mark Ronson ft Bruno Mars (Album: Uptown Special, Genre: Funk, Duration: 4:30)")

# %% [markdown]
# ### Test 2 — Search by Artist
#
# Choose:
#
# ```text
# 2
# ```
#
# Enter:
#
# ```text
# Ed Sheeran
# ```
#
# Expected results:
#
# ```text
# Searching for songs by artist: 'Ed Sheeran'
# Found: 'Shape of You' (Album: Divide, Genre: Pop, Duration: 3:53)
# Found: 'Perfect' (Album: Divide, Genre: Pop, Duration: 4:23)
# Found: 'Thinking Out Loud' (Album: Multiply, Genre: Pop, Duration: 4:41)
# ```
#
# Also test a different capitalization such as:
#
# ```text
# ed sheeran
# ```
#
# The search should still find the same songs.

# %%
# Test 2 — Search by Artist
print("Test input:")
print("2")
print("Ed Sheeran")
print()
print("Expected:")
print("Searching for songs by artist: 'Ed Sheeran'")
print("Found: 'Shape of You' (Album: Divide, Genre: Pop, Duration: 3:53)")
print("Found: 'Perfect' (Album: Divide, Genre: Pop, Duration: 4:23)")
print("Found: 'Thinking Out Loud' (Album: Multiply, Genre: Pop, Duration: 4:41)")

# %% [markdown]
# ### Test 3 — Song Title Not Found
#
# Choose:
#
# ```text
# 1
# ```
#
# Enter a title that does not exist, for example:
#
# ```text
# Unknown Song
# ```
#
# Expected:
#
# ```text
# Song title 'Unknown Song' does not exist in the database.
# ```
#
# The program should return to the menu.

# %%
# Test 3 — Song Title Not Found
print("Test input:")
print("1")
print("Unknown Song")
print()
print("Expected:")
print("Song title 'Unknown Song' does not exist in the database.")

# %% [markdown]
# ### Test 4 — Artist Not Found
#
# Choose:
#
# ```text
# 2
# ```
#
# Enter an artist that does not exist, for example:
#
# ```text
# Unknown Artist
# ```
#
# Expected:
#
# ```text
# No songs found for artist 'Unknown Artist'.
# ```
#
# The program should return to the menu.

# %%
# Test 4 — Artist Not Found
print("Test input:")
print("2")
print("Unknown Artist")
print()
print("Expected:")
print("No songs found for artist 'Unknown Artist'.")

# %% [markdown]
# ### Test 5 — Exit
#
# Choose:
#
# ```text
# 3
# ```
#
# Expected:
#
# ```text
# Exiting the Songs Management System. Goodbye!
# ```
#
# The program should leave the menu loop using `break`.
#
# Do **not** use `exit()`.

# %%
# Test 5 — Exit
print("Test input:")
print("3")
print()
print("Expected:")
print("Exiting the Songs Management System. Goodbye!")

# %% [markdown]
# ## Submission Checklist
#
# Before submitting, verify that:
#
# - [ ] `load_database()` is implemented.
# - [ ] `search_by_title()` is implemented.
# - [ ] `search_by_artist()` is implemented.
# - [ ] `main()` is implemented.
# - [ ] The program reads **exactly** `songs_database.txt`.
# - [ ] The database is loaded when the application starts.
# - [ ] Title searches are case-insensitive.
# - [ ] Artist searches are case-insensitive.
# - [ ] Multiple songs can be returned for an artist.
# - [ ] Missing titles are handled correctly.
# - [ ] Missing artists are handled correctly.
# - [ ] The menu matches the required format.
# - [ ] `break` is used to exit the menu.
# - [ ] `exit()` is not used.
# - [ ] The following appears at the bottom:
#
# ```python
# if __name__ == "__main__":
#     main()
# ```
#
# - [ ] All test scenarios have been verified.

# %% [markdown]
# ## Submission
#
# For the original Codio submission:
#
# - **File name:** `SC_Q3.py`
# - Develop and test your program locally or in this Colab notebook.
# - Copy only the contents of your completed Python script into Codio.
# - Do not rename `songs_database.txt`.
# - Run the built-in Codio tests before submitting.
#
# > **Important:** Automated checks may compare prompts and output messages exactly. Follow the required wording and formatting.
