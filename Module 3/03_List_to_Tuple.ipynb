# %% [markdown]
# # 1. List to Tuple
#
# You are given a list named `nums`.
#
# Write a Python program that converts this list into a Tuple and prints the resulting tuple.
#
# ### Requirements
#
# - The variable `nums` is already defined for you.
# - **Do not assign a new value to `nums`.**
# - Your solution should handle lists of varying lengths.
# - Convert the list into a tuple.
# - Print the resulting tuple.
#
# ### Example
#
# For:
#
# ```python
# nums = [79, 72, 99, 114]
# ```
#
# Your solution should produce:
#
# ```text
# (79, 72, 99, 114)
# ```
#
# ## Your Task
#
# Complete the **YOUR SOLUTION** cell below.

# %%
# DO NOT CHANGE THIS CELL

nums = [79, 72, 99, 114]

print("Input:")
print(nums)

# %% [markdown]
# ## YOUR SOLUTION
#
# Write your solution below.
#
# **Do not modify or reassign `nums`.**

# %%
# YOUR SOLUTION

# Write your code below.

# %% [markdown]
# ## Test Your Solution
#
# Run this cell after completing your solution.

# %%
# Test 1

expected = (79, 72, 99, 114)

try:
    assert result == expected
    print("Output:", result)
    print("✅ Test 1 passed!")
except NameError:
    print("❌ Test failed: Create a variable named 'result' containing the tuple.")
except AssertionError:
    print("❌ Test failed. Check your solution.")

# %% [markdown]
# ## Additional Tests
#
# These tests verify that your solution handles lists of different lengths.
#
# > You do not need to modify this cell.

# %%
# Additional tests

test_cases = [
    ([1], (1,)),
    ([], ()),
    ([10, 20, 30], (10, 20, 30)),
    ([5, 15, 25, 35, 45], (5, 15, 25, 35, 45))
]

for test_input, expected in test_cases:
    test_result = tuple(test_input)
    assert test_result == expected

print("✅ All additional tests passed!")

# %% [markdown]
# ## Hint
#
# Python provides a built-in `tuple()` function that converts a list into a tuple.
#
# For example:
#
# ```python
# tuple([1, 2, 3])
# ```
#
# produces:
#
# ```text
# (1, 2, 3)
# ```
