# %% [markdown]
# # 1. List to Tuple
#
# You are given a list named `nums`.
#
# Write a Python program that converts this list into a Tuple and prints the resulting tuple.
#
# ### Requirements
# - The variable `nums` is already defined for you.
# - **Do not assign a new value to `nums`.**
# - Your solution should work for lists of varying lengths.
# - Convert the list into a tuple.
# - Print the resulting tuple.
#
# ### Example
#
# For:
#
# ```python
# nums = [79, 72, 99, 114]
# ```
#
# Your solution should produce:
#
# ```text
# (79, 72, 99, 114)
# ```
#
# ### Your Task
#
# Complete the **YOUR SOLUTION** cell below.

# %%
# DO NOT CHANGE THIS CELL

nums = [79, 72, 99, 114]

print("Input:")
print(nums)

# %% [markdown]
# ## YOUR SOLUTION
#
# Write your solution in the cell below.
#
# Do not change the `nums` variable.

# %%
# YOUR SOLUTION

# Write your code below.

# %% [markdown]
# ## Test Your Solution
#
# Run the following cell after completing your solution.

# %%
# Test 1

expected = (79, 72, 99, 114)

try:
    assert nums_tuple == expected
    print("✅ Test 1 passed!")
except NameError:
    print("❌ Test failed: nums_tuple was not created.")
except AssertionError:
    print("❌ Test failed: Check your solution.")

# %% [markdown]
# ## Additional Tests
#
# The following tests check whether your solution works with lists of different lengths.
#
# > You do not need to modify this cell.

# %%
# Additional tests

test_cases = [
    ([1], (1,)),
    ([], ()),
    ([10, 20, 30], (10, 20, 30)),
    ([5, 15, 25, 35, 45], (5, 15, 25, 35, 45))
]

try:
    for test_input, expected in test_cases:
        test_result = tuple(test_input)
        assert test_result == expected

    print("✅ All additional tests passed!")
except AssertionError:
    print("❌ An additional test failed.")

# %% [markdown]
# ## Expected Solution
#
# The solution should convert `nums` into a tuple and print the resulting tuple.
#
# For the example input, the output should be:
#
# ```text
# (79, 72, 99, 114)
# ```
#
# **Do not add the solution to your submission if this notebook is being used as a graded assignment.**
